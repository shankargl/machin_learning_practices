# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
# Group by Category and calculate the sum of Sales
cat = df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
cat = df.groupby('Store')['Sales'].sum()
cat
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
cat = df.groupby(['Category','Store'])['Sales'].sum()
cat
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
now=df['Sales'].mean()
now
# Out:
# 187.5

# %%
ok=df['Sales'].agg(['mean','median','min','max','std','sum','count'])
ok
# Out:
# mean       187.500000
# median     190.000000
# min        100.000000
# max        300.000000
# std         66.062741
# sum       1500.000000
# count        8.000000
# Name: Sales, dtype: float64

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    593     21   John  January      Q1
# 1  2023-01-02       B   West    564     90   Mary  January      Q1
# 2  2023-01-03       C  North    923     26    Bob  January      Q1
# 3  2023-01-04       D  South    138     99  Alice  January      Q1
# 4  2023-01-05       A   East    621     92   John  January      Q1
# 5  2023-01-06       B   West    966     35   Mary  January      Q1
# 6  2023-01-07       C  North    352     16    Bob  January      Q1
# 7  2023-01-08       D  South    676     36  Alice  January      Q1
# 8  2023-01-09       A   East    545     14   John  January      Q1
# 9  2023-01-10       B   West    662     29   Mary  January      Q1
# 10 2023-01-11       C  North    784     16    Bob  January      Q1
# 11 2023-01-12       D  South    286     55  Alice  January      Q1
# 12 2023-01-13       A   East    748     76   John  January      Q1
# 13 2023-01-14       B   West    557     92   Mary  January      Q1
# 14 2023-01-15       C  North    205     17    Bob  January      Q1
# 15 2023-01-16       D  South    321     91  Alice  January      Q1
# 16 2023-01-17       A   East    194     17   John  January      Q1
# 17 2023-01-18       B   West    901     15   Mary  January      Q1
# 18 2023-01-19       C  North    886     90    Bob  January      Q1
# 19 2023-01-20       D  South    972     86  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index = 'Region',columns="Product",aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     593.0    NaN    NaN    NaN
# North      NaN    NaN  784.0    NaN
# South      NaN    NaN    NaN  321.0
# West       NaN  662.0    NaN    NaN

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %%
#operations using pandas

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='str')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df.describe()
# Out:
#                       Date       Sales      Units
# count                   20   20.000000  20.000000
# mean   2023-01-10 12:00:00  594.700000  50.650000
# min    2023-01-01 00:00:00  138.000000  14.000000
# 25%    2023-01-05 18:00:00  344.250000  17.000000
# 50%    2023-01-10 12:00:00  607.000000  35.500000
# 75%    2023-01-15 06:00:00  809.500000  90.000000
# max    2023-01-20 00:00:00  972.000000  99.000000
# std                    NaN  270.748495  34.096265
